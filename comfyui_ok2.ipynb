# %% [markdown]
# <a href="https://colab.research.google.com/github/zencolab/colab/blob/main/comfyui_ok2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==========================================
# 一、安装 ComfyUI 与依赖环境 (图像、视频与音频全能版)
# ==========================================
import os

# 1. 切换到主目录
# %cd /content

# 智能判断：防止重复克隆导致的 fatal 报错，并确保是最新版
if not os.path.exists("/content/ComfyUI/.git"):
    print("⏳ 正在拉取 ComfyUI 官方最新源码...")
    # !rm -rf /content/ComfyUI
    # !export GIT_TERMINAL_PROMPT=0 && git clone https://github.com/comfyanonymous/ComfyUI
else:
    print("✨ 检测到 ComfyUI 已存在，正在拉取最新核心更新...")
    # %cd /content/ComfyUI
    # !git pull

# 确保当前路径在 ComfyUI 内
# %cd /content/ComfyUI

# 2. 【核心升级】安装带有 CUDA 13.0 深度优化的 PyTorch (使用系统默认版，已注释)
#print("⏳ 正在安装 PyTorch 及其核心依赖 (基于 cu130)...")
#!pip install -q torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu130

# 3. 安装 ComfyUI 官方运行依赖
print("⏳ 正在安装 ComfyUI 官方运行依赖...")
# !pip install -q -r requirements.txt

# 4. 【关键配置】独立安装 huggingface_hub 和 hf_transfer，开启满速下载
print("⏳ 正在配置 Hugging Face 高速下载环境...")
# !pip install -q huggingface_hub hf_transfer

# 5. 【安装】视频处理插件包 (VideoHelperSuite)
print("⏳ 正在检查并安装高级视频处理插件包 (VideoHelperSuite)...")
# %cd /content/ComfyUI/custom_nodes
if not os.path.exists("ComfyUI-VideoHelperSuite/.git"):
    # !rm -rf ComfyUI-VideoHelperSuite
    # !export GIT_TERMINAL_PROMPT=0 && git clone https://github.com/Kosinkadink/ComfyUI-VideoHelperSuite.git
    # %cd ComfyUI-VideoHelperSuite
    # !pip install -q -r requirements.txt
    print("✅ 视频插件包 (VideoHelperSuite) 安装成功！")
else:
    print("✨ 视频插件包已存在，正在检查更新...")
    # %cd ComfyUI-VideoHelperSuite
    # !git pull

# 6. 【关键修复】安装音视频双修必备插件包 (KJNodes)，已修复正确的 Kijai 官方仓库地址！
print("⏳ 正在检查并安装音视频双修必备插件包 (KJNodes)...")
# %cd /content/ComfyUI/custom_nodes
if not os.path.exists("ComfyUI-KJNodes/.git"):
    # !rm -rf ComfyUI-KJNodes
    # !export GIT_TERMINAL_PROMPT=0 && git clone https://github.com/kijai/ComfyUI-KJNodes.git
    # %cd ComfyUI-KJNodes
    # !pip install -q -r requirements.txt
    print("✅ 音视频插件包 (KJNodes) 安装成功！")
else:
    print("✨ KJNodes 插件包已存在，正在检查更新...")
    # %cd ComfyUI-KJNodes
    # !git pull

# 7. 【重磅新增】安装 LTX-Video 官方插件包 (获取图生视频 LTXVImgToVideo 节点)
print("⏳ 正在检查并安装 LTX 官方扩展包 (ComfyUI-LTXVideo)...")
# %cd /content/ComfyUI/custom_nodes
if not os.path.exists("ComfyUI-LTXVideo/.git"):
    # !rm -rf ComfyUI-LTXVideo
    # !export GIT_TERMINAL_PROMPT=0 && git clone https://github.com/Lightricks/ComfyUI-LTXVideo.git
    # %cd ComfyUI-LTXVideo
    # !pip install -q -r requirements.txt
    print("✅ LTX 官方扩展包安装成功！")
else:
    print("✨ LTX 官方扩展包已存在，正在检查更新...")
    # %cd ComfyUI-LTXVideo
    # !git pull

# 恢复当前路径到 ComfyUI 根目录，以免影响后续操作
# %cd /content/ComfyUI

print("\n🎉 第一阶段完成：ComfyUI 核心升级完毕，图生视频与音视频双修环境已完全就绪！")
# Out:
# /content
# ✨ 检测到 ComfyUI 已存在，正在拉取最新核心更新...
# /content/ComfyUI
# Already up to date.
# /content/ComfyUI
# ⏳ 正在安装 ComfyUI 官方运行依赖...
# ⏳ 正在配置 Hugging Face 高速下载环境...
# ⏳ 正在检查并安装高级视频处理插件包 (VideoHelperSuite)...
# /content/ComfyUI/custom_nodes
# ✨ 视频插件包已存在，正在检查更新...
# /content/ComfyUI/custom_nodes/ComfyUI-VideoHelperSuite
# Already up to date.
# ⏳ 正在检查并安装音视频双修必备插件包 (KJNodes)...
# /content/ComfyUI/custom_nodes
# ✨ KJNodes 插件包已存在，正在检查更新...
# /content/ComfyUI/custom_nodes/ComfyUI-KJNodes
# Already up to date.
# ⏳ 正在检查并安装 LTX 官方扩展包 (ComfyUI-LTXVideo)...
# /content/ComfyUI/custom_nodes
# Cloning into 'ComfyUI-LTXVideo'...
# remote: Enumerating objects: 523, done.
# remote: Counting objects: 100% (249/249), done.
# remote: Compressing objects: 100% (117/117), done.
# remote: Total 523 (delta 163), reused 146 (delta 131), pack-reused 274 (from 1)
# Receiving objects: 100% (523/523), 12.63 MiB | 11.68 MiB/s, done.
# Resolving deltas: 100% (248/248), done.
# Filtering content: 100% (5/5), 10.98 MiB | 2.77 MiB/s, done.
# /content/ComfyUI/custom_nodes/ComfyUI-LTXVideo
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.8/422.8 kB 30.4 MB/s eta 0:00:00
# ✅ LTX 官方扩展包安装成功！
# /content/ComfyUI
#
# 🎉 第一阶段完成：ComfyUI 核心升级完毕，图生视频与音视频双修环境已完全就绪！

# %%
# ==========================================
# 二、终极模型下载列表 (Flux2 + LTX-2.3 音视频双修顶配版)
# ==========================================
import os
from google.colab import userdata
from huggingface_hub import hf_hub_download

# 1. ⚠️必须开启高速满速下载魔法！
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"

# 2. 从 Colab Secrets 中读取 HF Token
try:
    HF_TOKEN = userdata.get('HF_TOKEN')
    os.environ["HF_TOKEN"] = HF_TOKEN
except userdata.SecretNotFoundError:
    print("❌ 错误：请先在左侧 '🔑 Secrets' 中添加名为 'HF_TOKEN' 的密钥！")
    raise

# 3. 灵活配置下载任务列表 (共 12 个核心文件)
downloads = [
    # -------------------【第一部分：Flux 图像生态】-------------------
    {
        "repo_id": "stronman/flux2-dev",
        "filename": "split_files/diffusion_models/flux2_dev_fp8mixed.safetensors",
        "local_dir": "/content/ComfyUI/models/unet"
    },
    {
        "repo_id": "stronman/flux2-dev",
        "filename": "split_files/loras/Flux2TurboComfyv2.safetensors",
        "local_dir": "/content/ComfyUI/models/loras"
    },
    {
        "repo_id": "stronman/flux2-dev",
        "filename": "split_files/text_encoders/mistral_3_small_flux2_bf16.safetensors",
        "local_dir": "/content/ComfyUI/models/clip"
    },
    {
        "repo_id": "stronman/flux2-dev",
        "filename": "split_files/vae/flux2-vae.safetensors",
        "local_dir": "/content/ComfyUI/models/vae"
    },
    {
        "repo_id": "Shakker-Labs/FLUX.1-dev-ControlNet-Union-Pro-2.0",
        "filename": "diffusion_pytorch_model.safetensors",
        "local_dir": "/content/ComfyUI/models/controlnet"
    },
    {
        "repo_id": "xey/sldr_flux_nsfw_v2-studio",
        "filename": "sldr_flux_nsfw_v2-studio.safetensors",
        "local_dir": "/content/ComfyUI/models/loras"
    },

    # -------------------【第二部分：LTX-2.3 音视频生态】-------------------
    # 7. LTX-2.3 视频主模型
    {
        "repo_id": "stronman/LTX-2.3",
        "filename": "ltx-2.3-22b-dev.safetensors",
        "local_dir": "/content/ComfyUI/models/unet"
    },
    # 8. LTX-2.3 钦定 Gemma 3 大脑 (FP8 高清版)
    {
        "repo_id": "Comfy-Org/ltx-2",
        "filename": "split_files/text_encoders/gemma_3_12B_it_fp8_scaled.safetensors",
        "local_dir": "/content/ComfyUI/models/clip"
    },
    # 9. LTX-2.3 文本投影层 (解决维度冲突的关键)
    {
        "repo_id": "stronman/LTX2.3_comfy",
        "filename": "text_encoders/ltx-2.3_text_projection_bf16.safetensors",
        "local_dir": "/content/ComfyUI/models/clip"
    },
    # 10. 通用辅助文本编码器 CLIP-L
    {
        "repo_id": "comfyanonymous/flux_text_encoders",
        "filename": "clip_l.safetensors",
        "local_dir": "/content/ComfyUI/models/clip"
    },
    # 11. 【更新】LTX-2.3 专用视频 VAE (适配 KJNodes)
    {
        "repo_id": "stronman/LTX2.3_comfy",
        "filename": "vae/LTX23_video_vae_bf16.safetensors",
        "local_dir": "/content/ComfyUI/models/vae"
    },
    # 12. 【新增】LTX-2.3 专用音频 VAE (适配 KJNodes)
    {
        "repo_id": "stronman/LTX2.3_comfy",
        "filename": "vae/LTX23_audio_vae_bf16.safetensors",
        "local_dir": "/content/ComfyUI/models/vae"
    }
]

print(f"\n🚀 开始满速同步指定的 {len(downloads)} 个模型文件...\n")

for i, task in enumerate(downloads, 1):
    repo = task["repo_id"]
    file_path = task["filename"]
    target_dir = task["local_dir"]
    file_name = file_path.split('/')[-1]

    print(f"[{i}/{len(downloads)}] 正在从 {repo} 同步: {file_name}")
    try:
        hf_hub_download(
            repo_id=repo,
            filename=file_path,
            local_dir=target_dir,
            repo_type="model"
        )
        print(f"✅ 已完成并存放到: {target_dir}\n")
    except Exception as e:
        print(f"❌ 下载失败 ({file_name}): {e}\n")

print("🎉 恭喜！12 个满血核心组件全部归位，音视频同步生成环境已就绪！")
# Out:
# 🚀 开始满速同步指定的 12 个模型文件...
#
# [1/12] 正在从 stronman/flux2-dev 同步: flux2_dev_fp8mixed.safetensors
# ✅ 已完成并存放到: /content/ComfyUI/models/unet
#
# [2/12] 正在从 stronman/flux2-dev 同步: Flux2TurboComfyv2.safetensors
# ✅ 已完成并存放到: /content/ComfyUI/models/loras
#
# [3/12] 正在从 stronman/flux2-dev 同步: mistral_3_small_flux2_bf16.safetensors
# ✅ 已完成并存放到: /content/ComfyUI/models/clip
#
# [4/12] 正在从 stronman/flux2-dev 同步: flux2-vae.safetensors
# ✅ 已完成并存放到: /content/ComfyUI/models/vae
#
# [5/12] 正在从 Shakker-Labs/FLUX.1-dev-ControlNet-Union-Pro-2.0 同步: diffusion_pytorch_model.safetensors
# ✅ 已完成并存放到: /content/ComfyUI/models/controlnet
#
# [6/12] 正在从 xey/sldr_flux_nsfw_v2-studio 同步: sldr_flux_nsfw_v2-studio.safetensors
# ✅ 已完成并存放到: /content/ComfyUI/models/loras
#
# [7/12] 正在从 stronman/LTX-2.3 同步: ltx-2.3-22b-dev.safetensors
# ✅ 已完成并存放到: /content/ComfyUI/models/unet
#
# [8/12] 正在从 Comfy-Org/ltx-2 同步: gemma_3_12B_it_fp8_scaled.safetensors
# ✅ 已完成并存放到: /content/ComfyUI/models/clip
#
# [9/12] 正在从 stronman/LTX2.3_comfy 同步: ltx-2.3_text_projection_bf16.safetensors
# ✅ 已完成并存放到: /content/ComfyUI/models/clip
#
# [10/12] 正在从 comfyanonymous/flux_text_encoders 同步: clip_l.safetensors
# ✅ 已完成并存放到: /content/ComfyUI/models/clip
#
# [11/12] 正在从 stronman/LTX2.3_comfy 同步: LTX23_video_vae_bf16.safetensors
# vae/LTX23_video_vae_bf16.safetensors:   0%|          | 0.00/1.45G [00:00<?, ?B/s]
# ✅ 已完成并存放到: /content/ComfyUI/models/vae
#
# [12/12] 正在从 stronman/LTX2.3_comfy 同步: LTX23_audio_vae_bf16.safetensors
# vae/LTX23_audio_vae_bf16.safetensors:   0%|          | 0.00/365M [00:00<?, ?B/s]
# ✅ 已完成并存放到: /content/ComfyUI/models/vae
#
# 🎉 恭喜！12 个满血核心组件全部归位，音视频同步生成环境已就绪！

# %%
# ==========================================
# 三、内网穿透配置 (只需运行一次)
# ==========================================
import os
from google.colab import userdata

# 1. 读取 Colab Secrets
try:
    VPS_IP = userdata.get('VPS_IP')
    FRP_TOKEN = userdata.get('FRP_TOKEN')
except Exception as e:
    print("❌ 错误：无法读取 Secrets！请检查左侧是否填写并开启了 'VPS_IP' 和 'FRP_TOKEN'。")
    raise e

# 2. 下载并解压 FRP 客户端
# %cd /content
if not os.path.exists("/content/frp_0.56.0_linux_amd64"):
    print("⏳ 正在下载并解压 FRP 客户端...")
    # !wget -q https://github.com/fatedier/frp/releases/download/v0.56.0/frp_0.56.0_linux_amd64.tar.gz
    # !tar -xzf frp_0.56.0_linux_amd64.tar.gz
    # !rm frp_0.56.0_linux_amd64.tar.gz

# 3. 动态生成并写入配置文件
print("⏳ 正在生成 frpc.toml 配置文件...")
frpc_config_content = f"""
serverAddr = "{VPS_IP}"
serverPort = 7000
auth.token = "{FRP_TOKEN}"

[[proxies]]
name = "comfyui_web"
type = "tcp"
localIP = "127.0.0.1"
localPort = 8188
remotePort = 8080
"""

with open("/content/frp_0.56.0_linux_amd64/frpc.toml", "w", encoding="utf-8") as f:
    f.write(frpc_config_content.strip())

print("✅ FRP 配置文件生成完毕！")
# Out:
# /content
# ⏳ 正在下载并解压 FRP 客户端...
# ⏳ 正在生成 frpc.toml 配置文件...
# ✅ FRP 配置文件生成完毕！

# %%
# ==========================================
# 四、启动 FRP 和 ComfyUI (重启界面时运行)
# ==========================================
import subprocess
import threading
from google.colab import userdata

# 获取 IP 仅为了在控制台友好地打印访问链接
try:
    VPS_IP = userdata.get('VPS_IP')
except:
    VPS_IP = "你的公网IP"

# 1. 在后台新线程启动 FRP (读取刚才生成的配置文件)
def start_frpc():
    subprocess.run(["/content/frp_0.56.0_linux_amd64/frpc", "-c", "/content/frp_0.56.0_linux_amd64/frpc.toml"])

print("⏳ 正在后台唤起 FRP 穿透服务...")
threading.Thread(target=start_frpc, daemon=True).start()

print("============================================================")
print("✅ FRP 穿透已就绪！")
print(f"👉 启动完成后，请通过浏览器访问: http://{VPS_IP}:8080")
print("============================================================\n")

# 2. 启动 ComfyUI 主程序
print("⏳ 正在启动 ComfyUI 主进程...\n")
# %cd /content/ComfyUI
# !python main.py --dont-print-server
# Out:
# ⏳ 正在后台唤起 FRP 穿透服务...
# ============================================================
# ✅ FRP 穿透已就绪！
# 👉 启动完成后，请通过浏览器访问: http://34.153.197.18:8080
# ============================================================
#
# ⏳ 正在启动 ComfyUI 主进程...
#
# /content/ComfyUI
# WARNING: You need pytorch with cu130 or higher to use optimized CUDA operations.
# Found comfy_kitchen backend cuda: {'available': True, 'disabled': True, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8', 'scaled_mm_nvfp4']}
# Found comfy_kitchen backend triton: {'available': True, 'disabled': True, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8']}
# Found comfy_kitchen backend eager: {'available': True, 'disabled': False, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'dequantize_mxfp8', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8', 'scaled_mm_mxfp8', 'scaled_mm_nvfp4']}
# Checkpoint files will always be loaded safely.
# Total VRAM 81153 MB, total RAM 171061 MB
# pytorch version: 2.10.0+cu128
# Set vram state to: NORMAL_VRAM
# Device: cuda:0 NVIDIA A100-SXM4-80GB : cudaMallocAsync
# Using async weight offloading with 2 streams
# Enabled pinned memory 153954.0
# working around nvidia conv3d memory bug.
# Using pytorch attention
# aimdo: src/control.c:68:INFO:comfy-aimdo inited for GPU: NVIDIA A100-SXM4-80GB (VRAM: 81152 MB)
# DynamicVRAM support detected and enabled
# Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# ComfyUI version: 0.18.1
# comfy-aimdo version: 0.2.12
# comfy-kitchen version: 0.2.8
# ComfyUI frontend version: 1.42.8
# [Prompt Server] web root: /usr/local/lib/python3.12/dist-packages/comfyui_frontend_package/static
# Asset seeder disabled
# NumExpr defaulting to 12 threads.
#
# Import times for custom nodes:
#    0.0 seconds: /content/ComfyUI/custom_nodes/websocket_image_save.py
#    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-KJNodes
#    0.1 seconds: /content/ComfyUI/custom_nodes/ComfyUI-VideoHelperSuite
#    1.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-LTXVideo
#
# Context impl SQLiteImpl.
# Will assume non-transactional DDL.
# [DEPRECATION WARNING] Detected import of deprecated legacy API: /extensions/core/widgetInputs.js. This is likely caused by a custom node extension using outdated APIs. Please update your extensions or contact the extension author for an updated version.
# got prompt
# Failed to validate prompt for output 9:
# * LoadImage 22:
#   - Custom validation failed for node: image - Invalid image file: f35.jpg
# Output will be ignored
# invalid prompt: {'type': 'prompt_outputs_failed_validation', 'message': 'Prompt outputs failed validation', 'details': '', 'extra_info': {}}
# got prompt
# Using pytorch attention in VAE
# Using pytorch attention in VAE
# VAE load device: cuda:0, offload device: cpu, dtype: torch.bfloat16
# CLIP/text encoder model load device: cuda:0, offload device: cpu, current: cpu, dtype: torch.float16
# Found quantization metadata version 1
# Detected mixed precision quantization
# Using mixed precision operations
# model weight dtype torch.bfloat16, manual cast: torch.bfloat16
# model_type FLUX
# lora key not loaded: transformer.transformer_blocks.10.attn.add_k_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.10.attn.add_k_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.10.attn.add_q_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.10.attn.add_q_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.10.attn.add_v_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.10.attn.add_v_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.10.attn.to_add_out.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.10.attn.to_add_out.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.10.attn.to_k.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.10.attn.to_k.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.10.attn.to_out.0.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.10.attn.to_out.0.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.10.attn.to_q.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.10.attn.to_q.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.10.attn.to_v.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.10.attn.to_v.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.10.ff.net.0.proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.10.ff.net.0.proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.10.ff.net.2.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.10.ff.net.2.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.10.ff_context.net.0.proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.10.ff_context.net.0.proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.10.ff_context.net.2.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.10.ff_context.net.2.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.10.norm1.linear.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.10.norm1.linear.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.10.norm1_context.linear.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.10.norm1_context.linear.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.11.attn.add_k_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.11.attn.add_k_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.11.attn.add_q_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.11.attn.add_q_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.11.attn.add_v_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.11.attn.add_v_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.11.attn.to_add_out.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.11.attn.to_add_out.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.11.attn.to_k.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.11.attn.to_k.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.11.attn.to_out.0.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.11.attn.to_out.0.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.11.attn.to_q.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.11.attn.to_q.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.11.attn.to_v.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.11.attn.to_v.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.11.ff.net.0.proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.11.ff.net.0.proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.11.ff.net.2.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.11.ff.net.2.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.11.ff_context.net.0.proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.11.ff_context.net.0.proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.11.ff_context.net.2.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.11.ff_context.net.2.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.11.norm1.linear.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.11.norm1.linear.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.11.norm1_context.linear.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.11.norm1_context.linear.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.12.attn.add_k_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.12.attn.add_k_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.12.attn.add_q_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.12.attn.add_q_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.12.attn.add_v_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.12.attn.add_v_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.12.attn.to_add_out.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.12.attn.to_add_out.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.12.attn.to_k.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.12.attn.to_k.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.12.attn.to_out.0.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.12.attn.to_out.0.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.12.attn.to_q.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.12.attn.to_q.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.12.attn.to_v.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.12.attn.to_v.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.12.ff.net.0.proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.12.ff.net.0.proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.12.ff.net.2.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.12.ff.net.2.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.12.ff_context.net.0.proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.12.ff_context.net.0.proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.12.ff_context.net.2.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.12.ff_context.net.2.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.12.norm1.linear.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.12.norm1.linear.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.12.norm1_context.linear.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.12.norm1_context.linear.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.13.attn.add_k_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.13.attn.add_k_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.13.attn.add_q_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.13.attn.add_q_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.13.attn.add_v_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.13.attn.add_v_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.13.attn.to_add_out.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.13.attn.to_add_out.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.13.attn.to_k.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.13.attn.to_k.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.13.attn.to_out.0.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.13.attn.to_out.0.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.13.attn.to_q.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.13.attn.to_q.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.13.attn.to_v.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.13.attn.to_v.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.13.ff.net.0.proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.13.ff.net.0.proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.13.ff.net.2.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.13.ff.net.2.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.13.ff_context.net.0.proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.13.ff_context.net.0.proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.13.ff_context.net.2.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.13.ff_context.net.2.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.13.norm1.linear.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.13.norm1.linear.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.13.norm1_context.linear.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.13.norm1_context.linear.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.14.attn.add_k_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.14.attn.add_k_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.14.attn.add_q_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.14.attn.add_q_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.14.attn.add_v_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.14.attn.add_v_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.14.attn.to_add_out.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.14.attn.to_add_out.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.14.attn.to_k.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.14.attn.to_k.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.14.attn.to_out.0.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.14.attn.to_out.0.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.14.attn.to_q.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.14.attn.to_q.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.14.attn.to_v.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.14.attn.to_v.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.14.ff.net.0.proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.14.ff.net.0.proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.14.ff.net.2.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.14.ff.net.2.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.14.ff_context.net.0.proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.14.ff_context.net.0.proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.14.ff_context.net.2.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.14.ff_context.net.2.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.14.norm1.linear.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.14.norm1.linear.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.14.norm1_context.linear.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.14.norm1_context.linear.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.15.attn.add_k_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.15.attn.add_k_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.15.attn.add_q_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.15.attn.add_q_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.15.attn.add_v_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.15.attn.add_v_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.15.attn.to_add_out.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.15.attn.to_add_out.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.15.attn.to_k.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.15.attn.to_k.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.15.attn.to_out.0.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.15.attn.to_out.0.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.15.attn.to_q.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.15.attn.to_q.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.15.attn.to_v.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.15.attn.to_v.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.15.ff.net.0.proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.15.ff.net.0.proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.15.ff.net.2.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.15.ff.net.2.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.15.ff_context.net.0.proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.15.ff_context.net.0.proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.15.ff_context.net.2.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.15.ff_context.net.2.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.15.norm1.linear.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.15.norm1.linear.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.15.norm1_context.linear.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.15.norm1_context.linear.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.16.attn.add_k_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.16.attn.add_k_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.16.attn.add_q_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.16.attn.add_q_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.16.attn.add_v_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.16.attn.add_v_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.16.attn.to_add_out.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.16.attn.to_add_out.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.16.attn.to_k.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.16.attn.to_k.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.16.attn.to_out.0.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.16.attn.to_out.0.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.16.attn.to_q.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.16.attn.to_q.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.16.attn.to_v.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.16.attn.to_v.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.16.ff.net.0.proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.16.ff.net.0.proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.16.ff.net.2.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.16.ff.net.2.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.16.ff_context.net.0.proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.16.ff_context.net.0.proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.16.ff_context.net.2.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.16.ff_context.net.2.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.16.norm1.linear.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.16.norm1.linear.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.16.norm1_context.linear.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.16.norm1_context.linear.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.17.attn.add_k_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.17.attn.add_k_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.17.attn.add_q_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.17.attn.add_q_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.17.attn.add_v_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.17.attn.add_v_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.17.attn.to_add_out.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.17.attn.to_add_out.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.17.attn.to_k.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.17.attn.to_k.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.17.attn.to_out.0.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.17.attn.to_out.0.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.17.attn.to_q.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.17.attn.to_q.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.17.attn.to_v.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.17.attn.to_v.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.17.ff.net.0.proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.17.ff.net.0.proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.17.ff.net.2.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.17.ff.net.2.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.17.ff_context.net.0.proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.17.ff_context.net.0.proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.17.ff_context.net.2.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.17.ff_context.net.2.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.17.norm1.linear.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.17.norm1.linear.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.17.norm1_context.linear.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.17.norm1_context.linear.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.18.attn.add_k_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.18.attn.add_k_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.18.attn.add_q_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.18.attn.add_q_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.18.attn.add_v_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.18.attn.add_v_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.18.attn.to_add_out.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.18.attn.to_add_out.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.18.attn.to_k.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.18.attn.to_k.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.18.attn.to_out.0.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.18.attn.to_out.0.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.18.attn.to_q.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.18.attn.to_q.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.18.attn.to_v.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.18.attn.to_v.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.18.ff.net.0.proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.18.ff.net.0.proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.18.ff.net.2.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.18.ff.net.2.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.18.ff_context.net.0.proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.18.ff_context.net.0.proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.18.ff_context.net.2.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.18.ff_context.net.2.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.18.norm1.linear.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.18.norm1.linear.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.18.norm1_context.linear.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.18.norm1_context.linear.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.8.attn.add_k_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.8.attn.add_k_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.8.attn.add_q_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.8.attn.add_q_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.8.attn.add_v_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.8.attn.add_v_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.8.attn.to_add_out.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.8.attn.to_add_out.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.8.attn.to_k.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.8.attn.to_k.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.8.attn.to_out.0.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.8.attn.to_out.0.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.8.attn.to_q.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.8.attn.to_q.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.8.attn.to_v.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.8.attn.to_v.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.8.ff.net.0.proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.8.ff.net.0.proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.8.ff.net.2.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.8.ff.net.2.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.8.ff_context.net.0.proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.8.ff_context.net.0.proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.8.ff_context.net.2.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.8.ff_context.net.2.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.8.norm1.linear.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.8.norm1.linear.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.8.norm1_context.linear.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.8.norm1_context.linear.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.9.attn.add_k_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.9.attn.add_k_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.9.attn.add_q_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.9.attn.add_q_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.9.attn.add_v_proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.9.attn.add_v_proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.9.attn.to_add_out.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.9.attn.to_add_out.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.9.attn.to_k.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.9.attn.to_k.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.9.attn.to_out.0.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.9.attn.to_out.0.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.9.attn.to_q.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.9.attn.to_q.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.9.attn.to_v.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.9.attn.to_v.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.9.ff.net.0.proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.9.ff.net.0.proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.9.ff.net.2.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.9.ff.net.2.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.9.ff_context.net.0.proj.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.9.ff_context.net.0.proj.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.9.ff_context.net.2.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.9.ff_context.net.2.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.9.norm1.linear.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.9.norm1.linear.lora_B.weight
# lora key not loaded: transformer.transformer_blocks.9.norm1_context.linear.lora_A.weight
# lora key not loaded: transformer.transformer_blocks.9.norm1_context.linear.lora_B.weight
# NOT LOADED diffusion_model.double_blocks.0.img_mod.lin.weight
# NOT LOADED diffusion_model.double_blocks.0.txt_mod.lin.weight
# NOT LOADED diffusion_model.double_blocks.1.img_mod.lin.weight
# NOT LOADED diffusion_model.double_blocks.1.txt_mod.lin.weight
# NOT LOADED diffusion_model.double_blocks.2.img_mod.lin.weight
# NOT LOADED diffusion_model.double_blocks.2.txt_mod.lin.weight
# NOT LOADED diffusion_model.double_blocks.3.img_mod.lin.weight
# NOT LOADED diffusion_model.double_blocks.3.txt_mod.lin.weight
# NOT LOADED diffusion_model.double_blocks.4.img_mod.lin.weight
# NOT LOADED diffusion_model.double_blocks.4.txt_mod.lin.weight
# NOT LOADED diffusion_model.double_blocks.5.img_mod.lin.weight
# NOT LOADED diffusion_model.double_blocks.5.txt_mod.lin.weight
# NOT LOADED diffusion_model.double_blocks.6.img_mod.lin.weight
# NOT LOADED diffusion_model.double_blocks.6.txt_mod.lin.weight
# NOT LOADED diffusion_model.double_blocks.7.img_mod.lin.weight
# NOT LOADED diffusion_model.double_blocks.7.txt_mod.lin.weight
# NOT LOADED diffusion_model.single_blocks.0.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.1.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.2.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.3.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.4.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.5.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.6.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.7.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.8.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.9.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.10.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.11.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.12.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.13.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.14.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.15.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.16.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.17.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.18.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.19.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.20.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.21.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.22.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.23.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.24.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.25.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.26.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.27.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.28.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.29.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.30.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.31.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.32.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.33.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.34.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.35.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.36.modulation.lin.weight
# NOT LOADED diffusion_model.single_blocks.37.modulation.lin.weight
# Requested to load Flux2TEModel_
# Model Flux2TEModel_ prepared for dynamic VRAM loading. 33080MB Staged. 0 patches attached. Force pre-loaded 60 weights: 600 KB.
# Model Flux2TEModel_ prepared for dynamic VRAM loading. 33080MB Staged. 0 patches attached. Force pre-loaded 60 weights: 600 KB.
# Requested to load Flux2
# Model Flux2 prepared for dynamic VRAM loading. 33813MB Staged. 140 patches attached.
#   0% 0/30 [00:00<?, ?it/s,   Model Initializing ...  ]ERROR lora diffusion_model.double_blocks.0.img_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.0.img_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.0.img_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.0.txt_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.0.txt_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.0.txt_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.0.img_attn.proj.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.0.img_mlp.0.weight shape '[36864, 6144]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.0.img_mlp.2.weight shape '[6144, 18432]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.0.txt_attn.proj.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.0.txt_mlp.0.weight shape '[36864, 6144]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.0.txt_mlp.2.weight shape '[6144, 18432]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.1.img_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.1.img_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.1.img_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.1.txt_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.1.txt_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.1.txt_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.1.img_attn.proj.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.1.img_mlp.0.weight shape '[36864, 6144]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.1.img_mlp.2.weight shape '[6144, 18432]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.1.txt_attn.proj.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.1.txt_mlp.0.weight shape '[36864, 6144]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.1.txt_mlp.2.weight shape '[6144, 18432]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.2.img_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.2.img_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.2.img_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.2.txt_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.2.txt_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.2.txt_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.2.img_attn.proj.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.2.img_mlp.0.weight shape '[36864, 6144]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.2.img_mlp.2.weight shape '[6144, 18432]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.2.txt_attn.proj.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.2.txt_mlp.0.weight shape '[36864, 6144]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.2.txt_mlp.2.weight shape '[6144, 18432]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.3.img_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.3.img_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.3.img_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.3.txt_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.3.txt_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.3.txt_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.3.img_attn.proj.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.3.img_mlp.0.weight shape '[36864, 6144]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.3.img_mlp.2.weight shape '[6144, 18432]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.3.txt_attn.proj.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.3.txt_mlp.0.weight shape '[36864, 6144]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.3.txt_mlp.2.weight shape '[6144, 18432]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.4.img_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.4.img_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.4.img_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.4.txt_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.4.txt_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.4.txt_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.4.img_attn.proj.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.4.img_mlp.0.weight shape '[36864, 6144]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.4.img_mlp.2.weight shape '[6144, 18432]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.4.txt_attn.proj.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.4.txt_mlp.0.weight shape '[36864, 6144]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.4.txt_mlp.2.weight shape '[6144, 18432]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.5.img_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.5.img_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.5.img_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.5.txt_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.5.txt_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.5.txt_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.5.img_attn.proj.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.5.img_mlp.0.weight shape '[36864, 6144]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.5.img_mlp.2.weight shape '[6144, 18432]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.5.txt_attn.proj.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.5.txt_mlp.0.weight shape '[36864, 6144]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.5.txt_mlp.2.weight shape '[6144, 18432]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.6.img_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.6.img_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.6.img_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.6.txt_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.6.txt_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.6.txt_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.6.img_attn.proj.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.6.img_mlp.0.weight shape '[36864, 6144]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.6.img_mlp.2.weight shape '[6144, 18432]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.6.txt_attn.proj.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.6.txt_mlp.0.weight shape '[36864, 6144]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.6.txt_mlp.2.weight shape '[6144, 18432]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.7.img_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.7.img_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.7.img_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.7.txt_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.7.txt_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.7.txt_attn.qkv.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.7.img_attn.proj.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.7.img_mlp.0.weight shape '[36864, 6144]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.7.img_mlp.2.weight shape '[6144, 18432]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.7.txt_attn.proj.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.double_blocks.7.txt_mlp.0.weight shape '[36864, 6144]' is invalid for input of size 37748736
# ERROR lora diffusion_model.double_blocks.7.txt_mlp.2.weight shape '[6144, 18432]' is invalid for input of size 37748736
# ERROR lora diffusion_model.single_blocks.0.linear1.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.single_blocks.0.linear1.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.single_blocks.0.linear1.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.single_blocks.0.linear1.weight shape '[24576, 6144]' is invalid for input of size 37748736
# ERROR lora diffusion_model.single_blocks.0.linear2.weight shape '[6144, 24576]' is invalid for input of size 47185920
# ERROR lora diffusion_model.single_blocks.1.linear1.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.single_blocks.1.linear1.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.single_blocks.1.linear1.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.single_blocks.1.linear1.weight shape '[24576, 6144]' is invalid for input of size 37748736
# ERROR lora diffusion_model.single_blocks.1.linear2.weight shape '[6144, 24576]' is invalid for input of size 47185920
# ERROR lora diffusion_model.single_blocks.2.linear1.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.single_blocks.2.linear1.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.single_blocks.2.linear1.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.single_blocks.2.linear1.weight shape '[24576, 6144]' is invalid for input of size 37748736
# ERROR lora diffusion_model.single_blocks.2.linear2.weight shape '[6144, 24576]' is invalid for input of size 47185920
# ERROR lora diffusion_model.single_blocks.3.linear1.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.single_blocks.3.linear1.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.single_blocks.3.linear1.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.single_blocks.3.linear1.weight shape '[24576, 6144]' is invalid for input of size 37748736
# ERROR lora diffusion_model.single_blocks.3.linear2.weight shape '[6144, 24576]' is invalid for input of size 47185920
# ERROR lora diffusion_model.single_blocks.4.linear1.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.single_blocks.4.linear1.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.single_blocks.4.linear1.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.single_blocks.4.linear1.weight shape '[24576, 6144]' is invalid for input of size 37748736
# ERROR lora diffusion_model.single_blocks.4.linear2.weight shape '[6144, 24576]' is invalid for input of size 47185920
# ERROR lora diffusion_model.single_blocks.5.linear1.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.single_blocks.5.linear1.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.single_blocks.5.linear1.weight shape '[6144, 6144]' is invalid for input of size 9437184
# ERROR lora diffusion_model.single_blocks.5.linear1.weight shape '[24576, 6144]' is invalid for input of size 37748736
# ...
#   File "/content/ComfyUI/comfy/patcher_extension.py", line 112, in execute
#     return self.original(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 995, in outer_sample
#     output = self.inner_sample(noise, latent_image, device, sampler, sigmas, denoise_mask, callback, disable_pbar, seed, latent_shapes=latent_shapes)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 981, in inner_sample
#     samples = executor.execute(self, sigmas, extra_args, callback, noise, latent_image, denoise_mask, disable_pbar)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/patcher_extension.py", line 112, in execute
#     return self.original(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 751, in sample
#     samples = self.sampler_function(model_k, noise, sigmas, extra_args=extra_args, callback=k_callback, disable=disable_pbar, **self.extra_options)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 124, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/k_diffusion/sampling.py", line 205, in sample_euler
#     denoised = model(x, sigma_hat * s_in, **extra_args)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 400, in __call__
#     out = self.inner_model(x, sigma, model_options=model_options, seed=seed)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 954, in __call__
#     return self.outer_predict_noise(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 961, in outer_predict_noise
#     ).execute(x, timestep, model_options, seed)
#       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/patcher_extension.py", line 112, in execute
#     return self.original(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 964, in predict_noise
#     return sampling_function(self.inner_model, x, timestep, self.conds.get("negative", None), self.conds.get("positive", None), self.cfg, model_options=model_options, seed=seed)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 380, in sampling_function
#     out = calc_cond_batch(model, conds, x, timestep, model_options)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 205, in calc_cond_batch
#     return _calc_cond_batch_outer(model, conds, x_in, timestep, model_options)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 213, in _calc_cond_batch_outer
#     return executor.execute(model, conds, x_in, timestep, model_options)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/patcher_extension.py", line 112, in execute
#     return self.original(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 325, in _calc_cond_batch
#     output = model.apply_model(input_x, timestep_, **c).chunk(batch_chunks)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/model_base.py", line 172, in apply_model
#     return comfy.patcher_extension.WrapperExecutor.new_class_executor(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/patcher_extension.py", line 112, in execute
#     return self.original(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/model_base.py", line 207, in _apply_model
#     t = self.process_timestep(t, x=x, **extra_conds)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/model_base.py", line 1078, in process_timestep
#     a_timestep = self.diffusion_model.a_patchifier.patchify(((audio_denoise_mask) * timestep.view([timestep.shape[0]] + [1] * (audio_denoise_mask.ndim - 1)))[:, :1, :, :1])[0]
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/ldm/lightricks/symmetric_patchifier.py", line 167, in patchify
#     b, _, t, _ = audio_latents.shape
#     ^^^^^^^^^^
# ValueError: too many values to unpack (expected 4)
#
# Prompt executed in 0.57 seconds
# got prompt
# Using pytorch attention in VAE
# Using pytorch attention in VAE
# VAE load device: cuda:0, offload device: cpu, dtype: torch.bfloat16
# CLIP/text encoder model load device: cuda:0, offload device: cpu, current: cpu, dtype: torch.float16
# Found quantization metadata version 1
# Detected mixed precision quantization
# Using mixed precision operations
# model weight dtype torch.bfloat16, manual cast: torch.bfloat16
# model_type FLUX
# Requested to load Flux2TEModel_
# Model Flux2TEModel_ prepared for dynamic VRAM loading. 33080MB Staged. 0 patches attached. Force pre-loaded 60 weights: 600 KB.
# Model Flux2TEModel_ prepared for dynamic VRAM loading. 33080MB Staged. 0 patches attached. Force pre-loaded 60 weights: 600 KB.
# Requested to load Flux2
# Model Flux2 prepared for dynamic VRAM loading. 33813MB Staged. 138 patches attached.
# 100% 8/8 [00:38<00:00,  4.75s/it]
# Requested to load AutoencoderKL
# Model AutoencoderKL prepared for dynamic VRAM loading. 160MB Staged. 0 patches attached.
# Prompt executed in 251.21 seconds
# got prompt
# VAE load device: cuda:0, offload device: cpu, dtype: torch.bfloat16
# Found quantization metadata version 1
# Using MixedPrecisionOps for text encoder
# CLIP/text encoder model load device: cuda:0, offload device: cpu, current: cpu, dtype: torch.float16
# Requested to load LTXAVTEModel_
# Model LTXAVTEModel_ prepared for dynamic VRAM loading. 14789MB Staged. 0 patches attached. Force pre-loaded 290 weights: 1497 KB.
# Model LTXAVTEModel_ prepared for dynamic VRAM loading. 14789MB Staged. 0 patches attached. Force pre-loaded 290 weights: 1497 KB.
# Requested to load VideoVAE
# Model VideoVAE prepared for dynamic VRAM loading. 1384MB Staged. 0 patches attached.
# model weight dtype torch.bfloat16, manual cast: None
# model_type FLUX
# Requested to load LTXAV
# Model LTXAV prepared for dynamic VRAM loading. 40053MB Staged. 0 patches attached.
#   0% 0/25 [00:00<?, ?it/s,   Model Initializing ...  ]
# !!! Exception during processing !!! too many values to unpack (expected 4)
# Traceback (most recent call last):
#   File "/content/ComfyUI/execution.py", line 534, in execute
#     output_data, output_ui, has_subgraph, has_pending_tasks = await get_output_data(prompt_id, unique_id, obj, input_data_all, execution_block_cb=execution_block_cb, pre_execute_cb=pre_execute_cb, v3_data=v3_data)
#                                                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/execution.py", line 334, in get_output_data
#     return_values = await _async_map_node_over_list(prompt_id, unique_id, obj, input_data_all, obj.FUNCTION, allow_interrupt=True, execution_block_cb=execution_block_cb, pre_execute_cb=pre_execute_cb, v3_data=v3_data)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/execution.py", line 308, in _async_map_node_over_list
#     await process_inputs(input_dict, i)
#   File "/content/ComfyUI/execution.py", line 296, in process_inputs
#     result = f(**inputs)
#              ^^^^^^^^^^^
#   File "/content/ComfyUI/nodes.py", line 1591, in sample
#     return common_ksampler(model, seed, steps, cfg, sampler_name, scheduler, positive, negative, latent_image, denoise=denoise)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/nodes.py", line 1556, in common_ksampler
#     samples = comfy.sample.sample(model, noise, steps, cfg, sampler_name, scheduler, positive, negative, latent_image,
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/sample.py", line 66, in sample
#     samples = sampler.sample(noise, positive, negative, cfg=cfg, latent_image=latent_image, start_step=start_step, last_step=last_step, force_full_denoise=force_full_denoise, denoise_mask=noise_mask, sigmas=sigmas, callback=callback, disable_pbar=disable_pbar, seed=seed)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 1180, in sample
#     return sample(self.model, noise, positive, negative, cfg, self.device, sampler, sigmas, self.model_options, latent_image=latent_image, denoise_mask=denoise_mask, callback=callback, disable_pbar=disable_pbar, seed=seed)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 1070, in sample
#     return cfg_guider.sample(noise, latent_image, sampler, sigmas, denoise_mask, callback, disable_pbar, seed)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 1052, in sample
#     output = executor.execute(noise, latent_image, sampler, sigmas, denoise_mask, callback, disable_pbar, seed, latent_shapes=latent_shapes)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/patcher_extension.py", line 112, in execute
#     return self.original(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 995, in outer_sample
#     output = self.inner_sample(noise, latent_image, device, sampler, sigmas, denoise_mask, callback, disable_pbar, seed, latent_shapes=latent_shapes)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 981, in inner_sample
#     samples = executor.execute(self, sigmas, extra_args, callback, noise, latent_image, denoise_mask, disable_pbar)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/patcher_extension.py", line 112, in execute
#     return self.original(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 751, in sample
#     samples = self.sampler_function(model_k, noise, sigmas, extra_args=extra_args, callback=k_callback, disable=disable_pbar, **self.extra_options)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 124, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/k_diffusion/sampling.py", line 205, in sample_euler
#     denoised = model(x, sigma_hat * s_in, **extra_args)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 400, in __call__
#     out = self.inner_model(x, sigma, model_options=model_options, seed=seed)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 954, in __call__
#     return self.outer_predict_noise(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 961, in outer_predict_noise
#     ).execute(x, timestep, model_options, seed)
#       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/patcher_extension.py", line 112, in execute
#     return self.original(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 964, in predict_noise
#     return sampling_function(self.inner_model, x, timestep, self.conds.get("negative", None), self.conds.get("positive", None), self.cfg, model_options=model_options, seed=seed)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 380, in sampling_function
#     out = calc_cond_batch(model, conds, x, timestep, model_options)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 205, in calc_cond_batch
#     return _calc_cond_batch_outer(model, conds, x_in, timestep, model_options)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 213, in _calc_cond_batch_outer
#     return executor.execute(model, conds, x_in, timestep, model_options)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/patcher_extension.py", line 112, in execute
#     return self.original(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/samplers.py", line 325, in _calc_cond_batch
#     output = model.apply_model(input_x, timestep_, **c).chunk(batch_chunks)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/model_base.py", line 172, in apply_model
#     return comfy.patcher_extension.WrapperExecutor.new_class_executor(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/patcher_extension.py", line 112, in execute
#     return self.original(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/model_base.py", line 207, in _apply_model
#     t = self.process_timestep(t, x=x, **extra_conds)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/model_base.py", line 1078, in process_timestep
#     a_timestep = self.diffusion_model.a_patchifier.patchify(((audio_denoise_mask) * timestep.view([timestep.shape[0]] + [1] * (audio_denoise_mask.ndim - 1)))[:, :1, :, :1])[0]
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ComfyUI/comfy/ldm/lightricks/symmetric_patchifier.py", line 167, in patchify
#     b, _, t, _ = audio_latents.shape
#     ^^^^^^^^^^
# ValueError: too many values to unpack (expected 4)
#
# Prompt executed in 32.08 seconds
